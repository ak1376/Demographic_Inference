# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load in the results from the preprocessing
with open("/sietch_colab/akapoor/Demographic_Inference/bottleneck_experiments_seed_42/sims/sims_pretrain_100_sims_inference_5_seed_42_num_replicates_3/preprocessing_results_obj.pkl", "rb") as f:
    results = pickle.load(f)

# %%
results['param_names']
# Out:
# ['N0', 'Nb', 'N_recover', 't_bottleneck_start', 't_bottleneck_end']

# %%
results['training']['predictions'].shape
# Out:
# (80, 3, 2, 5)

# %%
results['training']['targets'].shape
# Out:
# (80, 3, 2, 5)

# %%
results['training']['targets'][0,0,0,:]
# Out:
# array([ 1.01324972, -1.00112537, -0.91452283,  1.00458947,  0.05196152])

# %%
results['validation']['targets'][0,0,0,:]
# Out:
# array([ 0.9682164 , -0.8487049 ,  0.29791274,  0.25634352,  1.0738715 ])

# %%
plt.figure()
plt.hist(results['training']['predictions'][:,:,0,0].reshape(-1))
plt.title(f"Maximal value: {np.max(results['training']['predictions'][:,:,0,0].reshape(-1))}")
# Out:
# Text(0.5, 1.0, 'Maximal value: 15581.025215385636')

# %%
for i in np.arange(len(results['param_names'])):
    plt.figure()
    plt.hist(results['training']['predictions'][:,:,0,i])
    plt.suptitle(f'Dadi Results for {results["param_names"][i]}')
    plt.title(f"Min Value: {np.min(results['training']['predictions'][:,:,0,i]):.2f}, Max Value: {np.max(results['training']['predictions'][:,:,0,i]):.2f}")
    plt.show()

# %%
for i in np.arange(len(results['param_names'])):
    plt.figure()
    plt.hist(results['training']['predictions'][:,:,1,i])
    plt.suptitle(f'Moments Results for {results["param_names"][i]}')
    plt.title(f"Min Value: {np.min(results['training']['predictions'][:,:,1,i]):.2f}, Max Value: {np.max(results['training']['predictions'][:,:,1,i]):.2f}")
    plt.show()

# %% [markdown]
# I want to plot a particular parameter estimate's replicate values for a particular analysis

# %% [markdown]
# ## Let's examine the normalized target values

# %%
results['training']['targets'][:,:,0,i]
# Out:
# array([[ 0.05196152,  0.05196152,  0.05196152],
#        [-0.65817931, -0.65817931, -0.65817931],
#        [-1.61080725, -1.61080725, -1.61080725],
#        [-1.38564065, -1.38564065, -1.38564065],
#        [ 0.57157677,  0.57157677,  0.57157677],
#        [-0.77942286, -0.77942286, -0.77942286],
#        [-0.48497423, -0.48497423, -0.48497423],
#        [ 1.24707658,  1.24707658,  1.24707658],
#        [ 0.90066642,  0.90066642,  0.90066642],
#        [-0.03464102, -0.03464102, -0.03464102],
#        [ 0.05196152,  0.05196152,  0.05196152],
#        [ 1.62812776,  1.62812776,  1.62812776],
#        [ 1.61080725,  1.61080725,  1.61080725],
#        [-1.19511506, -1.19511506, -1.19511506],
#        [ 1.55884573,  1.55884573,  1.55884573],
#        [ 0.81406388,  0.81406388,  0.81406388],
#        [-0.77942286, -0.77942286, -0.77942286],
#        [ 0.57157677,  0.57157677,  0.57157677],
#        [ 1.57616623,  1.57616623,  1.57616623],
#        [-1.73205081, -1.73205081, -1.73205081],
# ...

# %%
for i in np.arange(len(results['param_names'])):
    plt.figure()
    plt.hist(results['training']['targets'][:,:,0,i])
    plt.suptitle(f'Target Values for {results["param_names"][i]}')
    plt.title(f'Number of elements that have a value of 0: {np.sum(results["training"]["targets"][:,:,0,i] == 0)}')
    # plt.title(f"Min Value: {np.min(results['training']['targets'][:,:,0,i]):.2f}, Max Value: {np.max(results['training']['targets'][:,:,0,i]):.2f}")
    plt.show()

# %%
# Load in the results from the preprocessing
with open("/sietch_colab/akapoor/Demographic_Inference/experiments/debug_yet_again_again/inference_results_obj.pkl", "rb") as f:
    inference_results = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Load in the results from the preprocessing
# ----> 2 with open("/sietch_colab/akapoor/Demographic_Inference/experiments/debug_yet_again_again/inference_results_obj.pkl", "rb") as f:
#       3     inference_results = pickle.load(f)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...

# %%
inference_results['features'].shape
# Out:
# (1, 2, 5)

# %%
inference_results['features'][:,0,:]
# Out:
# array([[13315.41625121,  4006.7466142 ,  5612.52559836,  2150.21721347,
#           699.89690704]])

# %%
inference_results['features'][:,1,:]
# Out:
# array([[156909.12228377,  62131.86991082,  80909.58867106,
#          84542.18618856,  60848.86272711]])

# %%
# Load in the results from the preprocessing
with open("/sietch_colab/akapoor/Demographic_Inference/experiments/two_layers_only/features_and_targets.pkl", "rb") as f:
    results = pickle.load(f)

# %%
results.keys()
# Out:
# dict_keys(['training', 'validation', 'testing'])

# %%
results['training']['targets']
# Out:
# array([[[[-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934],
#          [-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934]],
#
#         [[-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934],
#          [-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934]],
#
#         [[-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934],
#          [-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934]],
#
#         ...,
#
#         [[-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934],
#          [-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934]],
#
#         [[-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934],
#          [-1.21779877, -0.08806495,  0.77375065, -1.39238917,
#            0.89228934]],
#
#         [[-1.21779877, -0.08806495,  0.77375065, -1.39238917,
# ...

# %%
results['validation']['targets']
# Out:
# array([[[[-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132],
#          [-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132]],
#
#         [[-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132],
#          [-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132]],
#
#         [[-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132],
#          [-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132]],
#
#         [[-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132],
#          [-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132]],
#
#         [[-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132],
#          [-0.70548811, -1.53085233,  1.53518426, -1.46454183,
#            0.65211132]],
#
#         [[-0.70548811, -1.53085233,  1.53518426, -1.46454183,
# ...
