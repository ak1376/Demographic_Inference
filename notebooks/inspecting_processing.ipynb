# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
with open('/projects/kernlab/akapoor/Demographic_Inference/split_isolation_model_dadi_analysis_True_moments_analysis_True_momentsLD_analysis_True_seed_42/sims/sims_pretrain_5000_sims_inference_1_seed_42_num_replicates_3_top_values_2/preprocessing_results_obj.pkl', 'rb') as f:
    preprocessing_results = pickle.load(f)

# %%
preprocessing_results['training']['predictions']
# Out:
#       dadi_rep1_Na  moments_rep1_Na  moments_rep1_FIM_element_0  \
# 0     10018.307332     10053.193335                    0.238921
# 1     25829.194647     25891.907663                    0.180258
# 2      7957.000136      7976.517723                    0.227602
# 3     28616.423533     28656.138922                   -0.277980
# 4      5682.511770      5711.194938                    0.244775
# ...            ...              ...                         ...
# 3098  18072.065612     23852.440678                   -0.136517
# 3099  12464.459116     12523.665790                    0.241736
# 3100  10837.059297     10859.167511                   -0.082490
# 3101  19790.680447     19844.553272                    0.224161
# 3102  27652.643348     27700.122418                    0.088254
#
#       moments_rep1_FIM_element_1  moments_rep1_FIM_element_2  \
# 0                       0.371116                   -0.255156
# 1                       0.062313                   -0.144959
# ...

# %%
preprocessing_results['training']['targets']['simulated_params_N1']
# Out:
# 0       18253
# 1       20555
# 2        8024
# 3        7500
# 4       24880
#         ...
# 3098     8855
# 3099    21053
# 3100     2401
# 3101    22805
# 3102    13638
# Name: simulated_params_N1, Length: 3103, dtype: int64

# %%
plt.figure()
plt.scatter(preprocessing_results['training']['predictions']['dadi_rep1_N1'], preprocessing_results['training']['targets']['simulated_params_N1'])

# %%
import pickle
with open('/projects/kernlab/akapoor/Demographic_Inference/split_isolation_model_dadi_analysis_True_moments_analysis_True_momentsLD_analysis_True_seed_42/sims/sims_pretrain_5000_sims_inference_1_seed_42_num_replicates_3_top_values_2/features_and_targets.pkl', 'rb') as f:
    features_and_targets = pickle.load(f)

# %%
features_and_targets['training']['features']
# Out:
#       dadi_rep1_Na  moments_rep1_Na  moments_rep1_FIM_element_0  \
# 0     10018.307332     10053.193335                    0.238921
# 1     25829.194647     25891.907663                    0.180258
# 2      7957.000136      7976.517723                    0.227602
# 3     28616.423533     28656.138922                   -0.277980
# 4      5682.511770      5711.194938                    0.244775
# ...            ...              ...                         ...
# 3098  18072.065612     23852.440678                   -0.136517
# 3099  12464.459116     12523.665790                    0.241736
# 3100  10837.059297     10859.167511                   -0.082490
# 3101  19790.680447     19844.553272                    0.224161
# 3102  27652.643348     27700.122418                    0.088254
#
#       moments_rep1_FIM_element_1  moments_rep1_FIM_element_2  \
# 0                       0.371116                   -0.255156
# 1                       0.062313                   -0.144959
# ...

# %%
features_and_targets['training']['targets']
# Out:
#       simulated_params_Na  simulated_params_N1  simulated_params_N2  \
# 0               -0.641576             0.328851             0.104162
# 1                1.253885             0.603829             0.937935
# 2               -0.915717            -0.893022             1.133717
# 3                1.563982            -0.955614             0.821948
# 4               -1.178392             1.120458             0.518540
# ...                   ...                  ...                  ...
# 3098             0.309380            -0.793757            -0.409481
# 3099            -0.347366             0.663316             0.894813
# 3100            -0.550075            -1.564699             0.616371
# 3101             0.519257             0.872595             0.382962
# 3102             1.473677            -0.222419            -0.169860
#
#       simulated_params_t_split
# 0                    -0.354227
# 1                     0.556210
# 2                    -0.302176
# ...
